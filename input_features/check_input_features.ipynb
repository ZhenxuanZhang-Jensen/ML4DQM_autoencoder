# %%
import uproot

# %%
# events = uproot.open('root://cms-xrd-global.cern.ch//store/data/Run2016F/DisplacedJet/AOD/21Feb2020_UL2016_HIPM-v1/10000/2F69E749-2E6E-A54A-90A1-BFEF7665EC46.root')
# events = uproot.open('root://xrootd-cms.infn.it//store/data/Run2016B/DoubleEG/AOD/07Aug17_ver1-v1/10000/CADB27CB-079E-E711-8F4E-008CFAC942DC.root')
events = uproot.open('/eos/cms/store/user/fsiroky/data_secondrun/SingleElectron/crab_SingleElectronRun_2016E-18Apr2017-v1/170805_202120/0000/AODTree_1.root')
# xrootd-cms.infn.it

# %%
events['MyAnalysis/MyTree'].keys()
# Out:
# ['runId',
#  'lumiId',
#  'lumi',
#  'isSig',
#  'qPFJetPt',
#  'qPFJetEta',
#  'qPFJetPhi',
#  'qPFJet0Pt',
#  'qPFJet1Pt',
#  'qPFJet2Pt',
#  'qPFJet3Pt',
#  'qPFJet4Pt',
#  'qPFJet5Pt',
#  'qPFJet0Eta',
#  'qPFJet1Eta',
#  'qPFJet2Eta',
#  'qPFJet3Eta',
#  'qPFJet4Eta',
#  'qPFJet5Eta',
#  'qPFJet0Phi',
#  'qPFJet1Phi',
#  'qPFJet2Phi',
#  'qPFJet3Phi',
#  'qPFJet4Phi',
#  'qPFJet5Phi',
#  'qPFJet4CHS0Pt',
#  'qPFJet4CHS1Pt',
#  'qPFJet4CHS2Pt',
#  'qPFJet4CHS3Pt',
#  'qPFJet4CHS4Pt',
#  'qPFJet4CHS5Pt',
#  'qPFJet4CHS0Eta',
#  'qPFJet4CHS1Eta',
#  'qPFJet4CHS2Eta',
#  'qPFJet4CHS3Eta',
#  'qPFJet4CHS4Eta',
#  'qPFJet4CHS5Eta',
#  'qPFJet4CHS0Phi',
#  'qPFJet4CHS1Phi',
#  'qPFJet4CHS2Phi',
#  'qPFJet4CHS3Phi',
#  'qPFJet4CHS4Phi',
#  'qPFJet4CHS5Phi',
#  'qPFJet8CHS0Pt',
#  'qPFJet8CHS1Pt',
#  'qPFJet8CHS2Pt',
#  'qPFJet8CHS3Pt',
#  'qPFJet8CHS4Pt',
#  'qPFJet8CHS5Pt',
#  'qPFJet8CHS0Eta',
#  'qPFJet8CHS1Eta',
#  'qPFJet8CHS2Eta',
#  'qPFJet8CHS3Eta',
#  'qPFJet8CHS4Eta',
# ...

# %%
events.keys()
# Out:
# ['MyAnalysis;1', 'MyAnalysis/MyTree;1']
